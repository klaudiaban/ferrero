# %%
import pandas as pd

# %%
df = pd.read_csv('csv_files/zawiadomienia.csv', encoding='utf-8-sig', sep=";")

# %%
print(df.columns)
# Out:
# Index(['Zakład', 'Zawiadomienie', 'Rodzaj zawiadomienia', 'Utworzono dnia',
#        'Utworzone przez', 'Początek zakłócenia', 'Pocz. zakłóc. (godz.)',
#        'Koniec zakłócenia', 'Koniec zakłóc.(godz.)', 'Żądane rozpoczęcie',
#        'Żądana godzina rozp.', 'Żądane zakończenie', 'Żądana godz. zak.',
#        'Przestój', 'Urządzenie', 'Lokalizacja funkc.', 'Dotyczy urządzenia',
#        'Lokalizacja', 'Stanowisko robocze', 'Opis', 'Czas przestoju',
#        'Jedn. czasu przest.', 'Nr zlecenia', 'Status zawiadomienia', 'Opis.1',
#        'Notification Long Text', 'Grupa planistów', 'Wpływ',
#        'Dot. lokaliz. funkc.', 'Problem', 'Kod uszkodzenia',
#        'Tekst dot. szkody', 'Część obiektu', 'Kod części obiektu',
#        'Tek. kodu części ob.', 'Tekst pozycji', 'Przyczyna', 'Kod przyczyny',
#        'Tekst kodu przyczyny', 'Tekst przyczyny', 'Rodzaj zlecenia',
#        'Krótki tekst', 'Status systemu', 'Ozn. lokaliz. funkc.',
#        'Line functional location', 'Ozn. lokaliz. funkc..1',
#        'Oznaczenie obiektu', 'Oznaczenie obiektu.1'],
#       dtype='object')

# %%
df = df[["Zawiadomienie", "Rodzaj zawiadomienia", "Nr zlecenia", "Lokalizacja", "Lokalizacja funkc.", "Urządzenie", "Utworzono dnia", "Kod uszkodzenia", "Kod przyczyny", "Początek zakłócenia", "Koniec zakłócenia", "Pocz. zakłóc. (godz.)", "Koniec zakłóc.(godz.)", "Przestój", "Czas przestoju", "Jedn. czasu przest."]]
df.columns = ["ZawiadomienieId", "ZawiadomienieRodzaj", "ZlecenieId", "Lokalizacja", "LokalizacjaFunkcjonalnaId", "UrzadzenieId", "DataUtworzenia", "UszkodzenieId", "PrzyczynaId", "DataPoczatkuZaklocenia", "DataKoncaZaklocenia", "CzasPoczatkuZaklocenia", "CzasKoncaZaklocenia", "Przestoj", "CzasPrzestoju", "JednostkaCzasu"]
# Out:
#       ZawiadomienieId ZawiadomienieRodzaj    ZlecenieId Lokalizacja  \
# 0            12687308                  1P  5.000023e+10       UGP12
# 1            12670704                  1P  5.000022e+10       UGP43
# 2            12670754                  1P  5.000022e+10       UGP11
# 3            12670786                  1P  5.000022e+10       UGP42
# 4            12670788                  1P  5.000022e+10       UGP21
# ...               ...                 ...           ...         ...
# 2604         12707726                  PQ  5.000023e+10   UTILITIES
# 2605         12707745                  1P  5.000023e+10       UGP31
# 2606         12707755                  1P  5.000023e+10       UGP03
# 2607         12707957                  1P  5.000023e+10       UGP32
# 2608         12708097                  1P  5.000023e+10       UGP12
#
#      LokalizacjaFunkcjonalnaId  UrzadzenieId DataUtworzenia  UszkodzenieId  \
# 0       PLPA-PR-U12-011312-003    10127015.0     15.06.2025          107.0
# 1           PLPA-PR-U43-011446    10102247.0     01.06.2025          107.0
# 2           PLPA-PR-U11-010717    10166539.0     01.06.2025          112.0
# 3           PLPA-PR-U42-011646    10211795.0     01.06.2025          107.0
# 4       PLPA-PR-U21-010121-001    10103081.0     02.06.2025          107.0
# ...                        ...           ...            ...            ...
# 2604    PLPA-UT-001-100000-001    10081653.0     30.06.2025            NaN
# 2605    PLPA-PR-U43-011445-001    10101884.0     30.06.2025            NaN
# 2606        PLPA-PR-U32-012210    10166601.0     30.06.2025            NaN
# 2607        PLPA-PR-U32-012110    10179666.0     30.06.2025            NaN
# 2608    PLPA-PR-U12-010801-002    10217097.0     30.06.2025          109.0
#
#       PrzyczynaId DataPoczatkuZaklocenia DataKoncaZaklocenia  \
# 0             NaN             15.06.2025          21.07.2025
# 1           108.0             01.06.2025          01.06.2025
# 2           108.0             01.06.2025          01.06.2025
# 3           108.0             01.06.2025          01.06.2025
# 4           110.0             02.06.2025          03.06.2025
# ...           ...                    ...                 ...
# 2604          NaN             30.06.2025                 NaN
# 2605          NaN             30.06.2025                 NaN
# 2606          NaN             30.06.2025                 NaN
# 2607          NaN             30.06.2025                 NaN
# 2608          NaN             30.06.2025          01.07.2025
#
#      CzasPoczatkuZaklocenia CzasKoncaZaklocenia Przestoj CzasPrzestoju  \
# 0                  21:36:16            04:06:57        X      8,47E+02
# 1                  00:36:50            00:45:11        X      1,39E-01
# 2                  00:20:36            00:39:10        X      3,09E-01
# 3                  20:56:19            21:05:47        X      1,58E-01
# 4                  03:20:49            05:14:08        X      2,59E+01
# ...                     ...                 ...      ...           ...
# 2604               16:50:10            00:00:00      NaN      0,00E+00
# 2605               17:59:01            00:00:00        X      0,00E+00
# 2606               23:35:46            00:00:00        X      0,00E+00
# 2607               20:27:53            00:00:00        X      0,00E+00
# 2608               23:39:42            02:54:00      NaN      0,00E+00
#
#      JednostkaCzasu
# 0                 H
# 1                 H
# 2                 H
# 3                 H
# 4                 H
# ...             ...
# 2604              H
# 2605              H
# 2606              H
# 2607              H
# 2608              H
#
# [2609 rows x 16 columns]

# %%
df["ZawiadomienieId"] = pd.to_numeric(df["ZawiadomienieId"], errors="coerce", downcast="integer")
df["ZlecenieId"] = pd.to_numeric(df["ZlecenieId"], errors="coerce")
df["UrzadzenieId"] = pd.to_numeric(df["UrzadzenieId"], errors="coerce", downcast="integer")
df["UszkodzenieId"] = pd.to_numeric(df["UszkodzenieId"], errors="coerce", downcast="integer")
df["PrzyczynaId"] = pd.to_numeric(df["PrzyczynaId"], errors="coerce", downcast="integer")

date_cols = ["DataUtworzenia", "DataPoczatkuZaklocenia", "DataKoncaZaklocenia"]
for col in date_cols:
    df[col] = pd.to_datetime(df[col], format="%d.%m.%Y", errors="coerce").dt.date

time_cols = ["CzasPoczatkuZaklocenia", "CzasKoncaZaklocenia"]
for col in time_cols:
    df[col] = pd.to_datetime(df[col], format="%H:%M:%S", errors="coerce").dt.time
